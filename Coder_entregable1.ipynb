# %% [markdown]
# <a href="https://colab.research.google.com/github/johnthee/Coder/blob/main/Coder_entregable1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# ## Paso 2: Importar libreria de yahooo finance y descargar el historico de tesla

# %%
import yfinance as yf
tsla = yf.Ticker('TSLA')
#tsla.info

# %%
## sacar la informacion historica de un año hacia atras
hist = tsla.history(period = '1y')
hist['Date'] = hist.index
hist = hist.reset_index(drop = True)

# %%
hist.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits',
#        'Date', 'Close1'],
#       dtype='object')

# %% [markdown]
# ## Paso 3

# %%
# extraemos graficos rapidos
tickers = ['TSLA']
import matplotlib.pyplot as plt
for i, ticker in enumerate(tickers):
  current_ticker  = yf.Ticker(ticker)
  plt.subplot(len(tickers), 1, i+1)
  current_ticker.history(period = '365d')['Close'].plot(figsize = (16, 10), title = 'Precio historico de un anio para: '+ticker)

# %%
hist
# Out:
#            Open        High         Low       Close     Volume  Dividends  \
# 0    222.736664  225.166672  208.693329  213.100006  107390700        0.0
# 1    213.433334  220.970001  213.196671  216.759995   92641800        0.0
# 2    224.603333  243.576660  224.333328  237.036667  122793000        0.0
# 3    234.503326  246.833328  233.826660  236.086670  101107500        0.0
# 4    237.906662  239.316666  228.636673  235.070007  104202600        0.0
# ..          ...         ...         ...         ...        ...        ...
# 246  249.070007  252.419998  242.020004  244.399994  199882300        0.0
# 247  247.940002  250.970001  244.589996  249.830002  150337900        0.0
# 248  253.509995  259.679993  251.339996  258.709991  162384300        0.0
# 249  260.170013  261.570007  250.500000  256.790009  170575500        0.0
# 250  248.399994  258.950012  247.289993  255.899994  159150091        0.0
#
#      Stock Splits                      Date
# ...
